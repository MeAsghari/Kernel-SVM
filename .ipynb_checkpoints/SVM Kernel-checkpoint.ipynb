# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.svm import SVC , NuSVC
from sklearn.preprocessing import StandardScaler

# %%
data = np.loadtxt('data/ex2data2.txt', delimiter=',')

X = data[:, :-1].copy()
y = data[:, -1].copy().astype(np.int64)

normz = StandardScaler()
X = normz.fit_transform(X)

plt.scatter(X[:, 0], X[:, 1], c=y, cmap='jet');

# %% [markdown]
# ## `SVC`

# %% [markdown]
# ### *RBF*

# %%
model = SVC(C=1., kernel='rbf')
model.fit(X, y)
# Out:
# SVC()

# %%
n = 1000
xmin, xmax = X.min(0), X.max(0)
x1r = np.linspace(xmin[0], xmax[0], n)
x2r = np.linspace(xmin[1], xmax[1], n)
x1m, x2m = np.meshgrid(x1r, x2r)

Xm = np.stack((x1m.flatten(), x2m.flatten()), axis=1)
ym = model.decision_function(Xm)
ym = ym.reshape(x1m.shape)

plt.contour(x1m, x2m, ym, levels=[0], linewidths=3, colors='green');

plt.scatter(X[:, 0], X[:, 1], c=y, cmap='jet', s=50, zorder=3);

sv = model.support_vectors_
plt.scatter(sv[:, 0], sv[:, 1],  s=200, edgecolors='Purple');

# %% [markdown]
# ### *RBF with gamma='auto'*

# %%
model = SVC(C=1., kernel='rbf' , gamma='auto')
model.fit(X, y)
# Out:
# SVC(gamma='auto')

# %%
n = 1000
xmin, xmax = X.min(0), X.max(0)
x1r = np.linspace(xmin[0], xmax[0], n)
x2r = np.linspace(xmin[1], xmax[1], n)
x1m, x2m = np.meshgrid(x1r, x2r)

Xm = np.stack((x1m.flatten(), x2m.flatten()), axis=1)
ym = model.decision_function(Xm)
ym = ym.reshape(x1m.shape)

plt.contour(x1m, x2m, ym, levels=[0], linewidths=3, colors='green');

plt.scatter(X[:, 0], X[:, 1], c=y, cmap='jet', s=50, zorder=3);

sv = model.support_vectors_
plt.scatter(sv[:, 0], sv[:, 1],  s=200, edgecolors='Purple');

# %% [markdown]
# ### *Poly with degree = 2*

# %%
model = SVC(C=1., kernel='poly' , degree=2)
model.fit(X, y)
# Out:
# SVC(degree=2, kernel='poly')

# %%
n = 1000
xmin, xmax = X.min(0), X.max(0)
x1r = np.linspace(xmin[0], xmax[0], n)
x2r = np.linspace(xmin[1], xmax[1], n)
x1m, x2m = np.meshgrid(x1r, x2r)

Xm = np.stack((x1m.flatten(), x2m.flatten()), axis=1)
ym = model.decision_function(Xm)
ym = ym.reshape(x1m.shape)

plt.contour(x1m, x2m, ym, levels=[0], linewidths=3, colors='green');

plt.scatter(X[:, 0], X[:, 1], c=y, cmap='jet', s=50, zorder=3);

sv = model.support_vectors_
plt.scatter(sv[:, 0], sv[:, 1],  s=200, edgecolors='Purple');

# %% [markdown]
# ### *Poly with degree = 2 and c=0.1*

# %%
model = SVC(C=0.1, kernel='poly' , degree=2)
model.fit(X, y)
# Out:
# SVC(C=0.1, degree=2, kernel='poly')

# %%
n = 1000
xmin, xmax = X.min(0), X.max(0)
x1r = np.linspace(xmin[0], xmax[0], n)
x2r = np.linspace(xmin[1], xmax[1], n)
x1m, x2m = np.meshgrid(x1r, x2r)

Xm = np.stack((x1m.flatten(), x2m.flatten()), axis=1)
ym = model.decision_function(Xm)
ym = ym.reshape(x1m.shape)

plt.contour(x1m, x2m, ym, levels=[0], linewidths=3, colors='green');

plt.scatter(X[:, 0], X[:, 1], c=y, cmap='jet', s=50, zorder=3);

sv = model.support_vectors_
plt.scatter(sv[:, 0], sv[:, 1],  s=200, edgecolors='Purple');

# %% [markdown]
# ### *Poly with degree = 3*

# %%
model = SVC(C=1, kernel='poly' , degree=3)
model.fit(X, y)
# Out:
# SVC(C=1, kernel='poly')

# %%
n = 1000
xmin, xmax = X.min(0), X.max(0)
x1r = np.linspace(xmin[0], xmax[0], n)
x2r = np.linspace(xmin[1], xmax[1], n)
x1m, x2m = np.meshgrid(x1r, x2r)

Xm = np.stack((x1m.flatten(), x2m.flatten()), axis=1)
ym = model.decision_function(Xm)
ym = ym.reshape(x1m.shape)

plt.contour(x1m, x2m, ym, levels=[0], linewidths=3, colors='green');

plt.scatter(X[:, 0], X[:, 1], c=y, cmap='jet', s=50, zorder=3);

sv = model.support_vectors_
plt.scatter(sv[:, 0], sv[:, 1],  s=200, edgecolors='Purple');

# %% [markdown]
# ### *Poly with degree = 3 and coef0 = 1*

# %%
model = SVC(C=1, kernel='poly' , degree=3 , coef0=1)
model.fit(X, y)
# Out:
# SVC(C=1, coef0=1, kernel='poly')

# %%
n = 1000
xmin, xmax = X.min(0), X.max(0)
x1r = np.linspace(xmin[0], xmax[0], n)
x2r = np.linspace(xmin[1], xmax[1], n)
x1m, x2m = np.meshgrid(x1r, x2r)

Xm = np.stack((x1m.flatten(), x2m.flatten()), axis=1)
ym = model.decision_function(Xm)
ym = ym.reshape(x1m.shape)

plt.contour(x1m, x2m, ym, levels=[0], linewidths=3, colors='green');

plt.scatter(X[:, 0], X[:, 1], c=y, cmap='jet', s=50, zorder=3);

sv = model.support_vectors_
plt.scatter(sv[:, 0], sv[:, 1],  s=200, edgecolors='Purple');

# %% [markdown]
# ### *sigmoid*

# %%
model = SVC(C=1, kernel='sigmoid')
model.fit(X, y)
# Out:
# SVC(C=1, kernel='sigmoid')

# %%
n = 1000
xmin, xmax = X.min(0), X.max(0)
x1r = np.linspace(xmin[0], xmax[0], n)
x2r = np.linspace(xmin[1], xmax[1], n)
x1m, x2m = np.meshgrid(x1r, x2r)

Xm = np.stack((x1m.flatten(), x2m.flatten()), axis=1)
ym = model.decision_function(Xm)
ym = ym.reshape(x1m.shape)

plt.contour(x1m, x2m, ym, levels=[0], linewidths=3, colors='green');

plt.scatter(X[:, 0], X[:, 1], c=y, cmap='jet', s=50, zorder=3);

sv = model.support_vectors_
plt.scatter(sv[:, 0], sv[:, 1],  s=200, edgecolors='Purple');

# %% [markdown]
# ### *sigmoid with coef0 = 2*

# %%
model = SVC(C=1, kernel='sigmoid' , coef0=2)
model.fit(X, y)
# Out:
# SVC(C=1, coef0=2, kernel='sigmoid')

# %%
n = 1000
xmin, xmax = X.min(0), X.max(0)
x1r = np.linspace(xmin[0], xmax[0], n)
x2r = np.linspace(xmin[1], xmax[1], n)
x1m, x2m = np.meshgrid(x1r, x2r)

Xm = np.stack((x1m.flatten(), x2m.flatten()), axis=1)
ym = model.decision_function(Xm)
ym = ym.reshape(x1m.shape)

plt.contour(x1m, x2m, ym, levels=[0], linewidths=3, colors='green');

plt.scatter(X[:, 0], X[:, 1], c=y, cmap='jet', s=50, zorder=3);

sv = model.support_vectors_
plt.scatter(sv[:, 0], sv[:, 1],  s=200, edgecolors='Purple');

# %% [markdown]
# ## `NuSVC`

# %% [markdown]
# ### *kernel poly and nu=0.1*

# %%
model = NuSVC(nu=0.1, kernel='poly' , degree=3 , coef0=1)
model.fit(X, y)
# Out:
# NuSVC(coef0=1, kernel='poly', nu=0.1)

# %%
n = 1000
xmin, xmax = X.min(0), X.max(0)
x1r = np.linspace(xmin[0], xmax[0], n)
x2r = np.linspace(xmin[1], xmax[1], n)
x1m, x2m = np.meshgrid(x1r, x2r)

Xm = np.stack((x1m.flatten(), x2m.flatten()), axis=1)
ym = model.decision_function(Xm)
ym = ym.reshape(x1m.shape)

plt.contour(x1m, x2m, ym, levels=[0], linewidths=3, colors='green');

plt.scatter(X[:, 0], X[:, 1], c=y, cmap='jet', s=50, zorder=3);

sv = model.support_vectors_
plt.scatter(sv[:, 0], sv[:, 1],  s=200, edgecolors='Purple');

# %% [markdown]
# ### *kernel poly and nu=0.5*

# %%
model = NuSVC(nu=0.5, kernel='poly' , degree=3 , coef0=1)
model.fit(X, y)
# Out:
# NuSVC(coef0=1, kernel='poly')

# %%
n = 1000
xmin, xmax = X.min(0), X.max(0)
x1r = np.linspace(xmin[0], xmax[0], n)
x2r = np.linspace(xmin[1], xmax[1], n)
x1m, x2m = np.meshgrid(x1r, x2r)

Xm = np.stack((x1m.flatten(), x2m.flatten()), axis=1)
ym = model.decision_function(Xm)
ym = ym.reshape(x1m.shape)

plt.contour(x1m, x2m, ym, levels=[0], linewidths=3, colors='green');

plt.scatter(X[:, 0], X[:, 1], c=y, cmap='jet', s=50, zorder=3);

sv = model.support_vectors_
plt.scatter(sv[:, 0], sv[:, 1],  s=200, edgecolors='Purple');
